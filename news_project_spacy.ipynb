# %%
#!pip install newsapi-python
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import boto3
import json
import spacy
#from urllib.parse import quote

# set pandas to display full text and all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

# %%
from newsapi import *
# Init
newsapi = NewsApiClient(api_key='') #Enter your api key

# %%
# /v2/everything
all_articles = newsapi.get_everything(q='Australia Politics',
                                      
                                      from_param='2018-08-20',
                                      to='2018-08-02',
                                      language='en',
                                      sort_by='publishedAt',
                                      page=1,
                                      page_size=100
                                    
                                     )

# %%
#next(iter(all_articles))
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 798,
#  'articles': [{'source': {'id': None, 'name': 'Stuff.co.nz'},
#    'author': None,
#    'title': 'Leadership spill declared in Australia',
#    'description': "It's on in Australian politics. Prime Minister Malcolm Turnbull will recontest his position, challenging his agitators to put up or shut up.",
#    'url': 'https://www.stuff.co.nz/world/australia/106436672/Leadership-spill-declared-in-Australia',
#    'urlToImage': 'https://resources.stuff.co.nz/content/dam/images/1/r/d/1/z/j/image.related.StuffLandscapeSixteenByNine.620x349.1rdb28.png/1534807321159.jpg',
#    'publishedAt': '2018-08-20T23:18:46Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Louise Yaxley',
#    'title': 'Turnbull hangs on with 48-35 leadership ballot win over Dutton, reshuffle on the cards',
#    'description': 'Malcolm Turnbull is set to implement sweeping changes to his frontbench after narrowly surviving a leadership ballot against Peter Dutton',
#    'url': 'http://www.abc.net.au/news/2018-08-21/malcolm-turnbull-survives-leadership-challenge-from-peter-dutton/10146574',
#    'urlToImage': 'http://www.abc.net.au/news/image/10146612-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T23:17:51Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': "'Groundhog Day': businesses slam Turnbull Government's energy backflip",
#    'description': 'The lack of a clear energy policy — and six changes of Prime Minister — in the last decade has sapped business confidence, the Australian Industry Group has told the ABC.',
#    'url': 'http://www.abc.net.au/news/2018-08-21/groundhog-day-business-confidence-sapped-by-energy-policy/10146322',
#    'urlToImage': 'http://www.abc.net.au/news/image/8762858-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T22:28:31Z'},
#   {'source': {'id': None, 'name': 'Independentaustralia.net'},
#    'author': 'John Passant',
#    'title': "PRESS GALLERY REPORT: Is Turnbull's leadership running out of energy?",
#    'description': "IA's Canberra correspondent John Passant delivers his first report from the Press Gallery, just as Turnbull ditches the NEG over a #libspill. read now...",
#    'url': 'https://independentaustralia.net/politics/politics-display/press-gallery-report-is-turnbulls-leadership-running-out-of-energy,11808',
#    'urlToImage': 'https://independentaustralia.net/_lib/slir/w900-c4x3/i/article/img/article-11808-hero.jpg',
#    'publishedAt': '2018-08-20T22:00:00Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': 'Live: Dutton resigns after failed leadership challenge against Turnbull',
#    'description': 'Malcolm Turnbull emerges victorious after calling a Liberal leadership spill, beating Peter Dutton 48-35. But the narrowness of the victory is setting up more problems for the PM. Follow live.',
#    'url': 'http://www.abc.net.au/news/2018-08-21/politics-live-malcolm-turnbull-sees-off-peter-dutton-challenge/10146280',
#    'urlToImage': 'http://www.abc.net.au/news/image/10139842-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T21:50:31Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': 'Live: Malcolm Turnbull heads into party room meeting amid talk of leadership spill',
#    'description': "The Prime Minister's backers spent the morning talking down suggestions of a leadership spill, but now the party room meeting has kicked off that may see a challenge launched for Malcolm Turnbull's job. Follow live.",
#    'url': 'http://www.abc.net.au/news/2018-08-21/politics-live-malcolm-turnbull-in-partyroom-meeting/10146280',
#    'urlToImage': 'http://www.abc.net.au/news/image/10139842-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T21:50:31Z'},
#   {'source': {'id': None, 'name': 'Theconversation.com'},
#    'author': 'Frank Bongiorno, Professor of History, ANU College of Arts and Social Sciences, Australian National University',
#    'title': 'Your time starts now: how leadership instability and revenge became woven into our political fabric',
#    'description': "Our penchant for overturning political leaders didn't appear overnight. But it has been intensified through constant polls and, in the Liberals' case, the fact that the party allows it.",
#    'url': 'http://theconversation.com/your-time-starts-now-how-leadership-instability-and-revenge-became-woven-into-our-political-fabric-101806',
#    'urlToImage': 'https://images.theconversation.com/files/232687/original/file-20180820-30596-18y74cc.png?ixlib=rb-1.1.0&rect=0%2C0%2C4000%2C2000&q=45&auto=format&w=1356&h=668&fit=crop',
#    'publishedAt': '2018-08-20T20:02:50Z'},
#   {'source': {'id': None, 'name': 'Rawstory.com'},
#    'author': 'Alex Henderson, AlterNet',
#    'title': 'Will the end of the US empire be a soft landing or a total collapse?',
#    'description': 'History shows that empires, ultimately, are unsustainable. From the Soviet Union to the U.K. to the Roman Empire, imperialism carried much too heavy a heavy price tag for a long list of major global powers. But some empires suffered more painful endings than …',
#    'url': 'https://www.rawstory.com/2018/08/will-end-us-empire-soft-landing-total-collapse/',
#    'urlToImage': 'https://www.rawstory.com/wp-content/uploads/2018/03/trump-afp-800x430.jpg',
#    'publishedAt': '2018-08-20T19:52:18Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Tom Iggulden',
#    'title': "Coalition MP calls for 'wrecker' Abbott to quit as Turnbull prepares to address party room",
#    'description': 'Tony Abbott is shirtfronted by his own side, with Nationals backbencher and former AFL player Damien Drum taking the former prime minister on, as leadership tensions build in the Government.',
#    'url': 'http://www.abc.net.au/news/2018-08-21/coalition-mp-calls-for-tony-abbott-to-quit-federal-parliament/10145006',
#    'urlToImage': 'http://www.abc.net.au/news/image/10145016-16x9-700x394.png',
#    'publishedAt': '2018-08-20T19:51:25Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Simon Elvery',
#    'title': "Are you average? If not, algorithms might 'screw' you",
#    'description': 'As governments and corporations start to rely more on algorithms to make decisions without human input, they\'ll "screw [some] people by default", a visiting professor warns.',
#    'url': 'http://www.abc.net.au/news/2018-08-21/algorithmic-decisions-accountability-fears/10139612',
#    'urlToImage': 'http://www.abc.net.au/news/image/10144556-16x9-700x394.png',
#    'publishedAt': '2018-08-20T19:06:02Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Laura Tingle',
#    'title': 'Turnbull at the mercy of a small and ruthless rump in his own party',
#    'description': 'Despite all the noise, what Canberra proved yesterday was that for now there is little appetite in the Coalition for a leadership change — in the sense of its transactional costs — and no clear view that Peter Dutton would produce a better election result, wr…',
#    'url': 'http://www.abc.net.au/news/2018-08-21/malcolm-turnbull-at-mercy-of-small-ruthless-rump-leadership/10144964',
#    'urlToImage': 'http://www.abc.net.au/news/image/9452284-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T19:04:38Z'},
#   {'source': {'id': None, 'name': 'Theatlantic.com'},
#    'author': 'James K. Galbraith',
#    'title': 'The Greece Bailout’s Legacy of Immiseration',
#    'description': 'The cynicism and brutality of what happened there is for the whole world to see.',
#    'url': 'https://www.theatlantic.com/international/archive/2018/08/greece-bailout-imf-europe/567892/',
#    'urlToImage': 'https://cdn.theatlantic.com/assets/media/img/mt/2018/08/GettyImages_187085593/facebook.jpg?1534790186',
#    'publishedAt': '2018-08-20T18:24:42Z'},
#   {'source': {'id': None, 'name': 'Seattlepi.com'},
#    'author': 'By ERIC TALMADGE, Associated Press',
#    'title': "Tourists go off beaten path on North Korea's sacred volcano",
#    'description': "MOUNT PAEKTU, North Korea (AP) — Foreign tourists looking to go off the beaten path in North Korea can now camp out on the country's biggest volcano. Hoping to open up a side of North Korea rarely seen by outsiders, a New Zealander who has extensive experienc…",
#    'url': 'https://www.seattlepi.com/news/crime/article/headline-Tourists-go-off-beaten-path-on-North-13167371.php',
#    'urlToImage': 'https://s.hdnux.com/photos/75/13/42/16038055/5/rawImage.jpg',
#    'publishedAt': '2018-08-20T17:34:22Z'},
#   {'source': {'id': None, 'name': 'Stuff.co.nz'},
#    'author': 'Philip Matthews',
#    'title': 'Taking the Nauru kids makes moral and political sense',
#    'description': 'EDITORIAL: Nauru is barely a speck in the ocean. At 21 square kilometres, the island is marginally smaller than Rangitoto in the Hauraki Gulf. And size matters in this case because when politicians descend on tiny Nauru for the Pacific Islands Forum in Septem…',
#    'url': 'http://www.stuff.co.nz/the-press/opinion/106402912/Taking-the-Nauru-kids-makes-moral-and-political-sense',
#    'urlToImage': 'https://resources.stuff.co.nz/content/dam/images/1/r/b/z/6/t/image.related.StuffLandscapeSixteenByNine.620x349.1rcl0g.png/1534737799024.jpg',
#    'publishedAt': '2018-08-20T17:00:00Z'},
#   {'source': {'id': None, 'name': 'Nzherald.co.nz'},
#    'author': 'newsfeeds@nzherald.co.nz',
#    'title': 'Editorial: Australia could get yet another PM',
#    'description': "Any time New Zealanders get despondent about their politics they can look across the Tasman. It is more than 10 years since Prime Minister John Howard's four-term Government was defeated and, since then, Australia's main parties have...",
#    'url': 'https://www.nzherald.co.nz/opinion/news/article.cfm?c_id=466&objectid=12110283',
#    'urlToImage': 'https://www.nzherald.co.nz/resizer/8UryIHJUq0Ldu6PFUaj1O8yCdmc=/1200x0/smart/filters:quality(70)/arc-anglerfish-syd-prod-nzme.s3.amazonaws.com/public/BJRQM3DNRJCN3O4F2DVICP55AE.jpg',
#    'publishedAt': '2018-08-20T17:00:00Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Sam Jacobs',
#    'title': 'With Canberra in chaos, the ASX is sinking',
#    'description': 'The ASX200 is down almost 1% in midday trade following another wild morning in federal politics. While not linking the decline directly to events in Canberra today, Richard Coppleson from Bell Potter Securities says markets loathe political uncertainty and th…',
#    'url': 'https://www.businessinsider.com.au/liberal-leadership-turmoil-asx-falls-2018-8',
#    'urlToImage': 'https://edge.alluremedia.com.au/uploads/businessinsider/2018/08/freefall-640x360.jpg',
#    'publishedAt': '2018-08-20T16:59:47Z'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Tom Chivers',
#    'title': 'Why not wreck the planet? It might get you elected',
#    'description': 'There is a certain mindset in politics, present the world over and across the political spectrum, which distrusts expertise -- especially scientific expertise, says Tom Chivers.',
#    'url': 'https://www.cnn.com/2018/08/20/opinions/populist-skeptics-science-opinion-intl/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/170316170427-bleached-coral-great-barrier-reef-staghorn-super-tease.jpeg',
#    'publishedAt': '2018-08-20T16:35:10Z'},
#   {'source': {'id': None, 'name': 'Freerepublic.com'},
#    'author': 'American Thinker',
#    'title': 'Australian PM drops climate change policy',
#    'description': 'Facing a serious threat to his leadership of the LiberalÂ Party in Australia, Prime Minister Malcolm Turnbull has scrapped his plans to set emissions targets in his signature energy policy.Â The emissions targets have generated large-scale opposition in his p…',
#    'url': 'https://www.freerepublic.com/focus/f-news/3680671/posts',
#    'urlToImage': None,
#    'publishedAt': '2018-08-20T16:21:30Z'},
#   {'source': {'id': None, 'name': 'Yahoo.com'},
#    'author': None,
#    'title': 'Beyond climate change despair, Sympathy for the Iranian people amid fresh sanctions, Saudi Arabia’s odd response to a Canadian tweet, Australia and New Zealand wake up to China’s power play, Lula’s long-shot bid for a third term as Brazil’s president',
#    'description': 'The Guardian / London',
#    'url': 'https://www.yahoo.com/news/beyond-climate-change-despair-sympathy-iranian-people-amid-160819752--politics.html',
#    'urlToImage': 'https://s.yimg.com/os/mit/media/m/social/images/social_default_logo-1481777.png',
#    'publishedAt': '2018-08-20T16:08:19Z'},
#   {'source': {'id': None, 'name': 'Alternet.org'},
#    'author': 'Alex Henderson, AlterNet',
#    'title': 'Will the End of the US Empire Be a Soft Landing or a Total Collapse?',
#    'description': '<!-- All divs have been put onto one line because of whitespace issues when rendered inline in browsers --> History shows that empires, ultimately, are unsustainable. <!-- All divs have been put onto one line because of whitespace issues when rendered inline …',
#    'url': 'https://www.alternet.org/news-amp-politics/will-end-us-empire-be-soft-landing-or-total-collapse',
#    'urlToImage': 'https://www.alternet.org/sites/default/files/story_images/screen_shot_2018-08-20_at_12.03.17_pm.png',
#    'publishedAt': '2018-08-20T15:48:00Z'},
#   {'source': {'id': None, 'name': 'Upi.com'},
#    'author': None,
#    'title': 'Australia reins in climate change plan over lack of support',
#    'description': "In a surprise move Monday, Australian PM Malcolm Turnbull said he will back down from plans to reduce climate change goals set out in the nation's energy plan.",
#    'url': 'https://www.upi.com/Top_News/World-News/2018/08/20/Australia-reins-in-climate-change-plan-over-lack-of-support/6321534772740/',
#    'urlToImage': 'https://cdnph.upi.com/sv/ph/og/upi_com/6321534772740/2018/1/8bacf6fe5a39f53a9afdbb0d2cb2fb28/v1.5/Australia-reins-in-climate-change-plan-over-lack-of-support.jpg',
#    'publishedAt': '2018-08-20T15:40:28Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Sam Jacobs',
#    'title': 'Political uncertainty just sent a key measure of Australian household confidence to its lowest level of the year',
#    'description': 'ANZ’s consumer sentiment survey fell sharply last week. ANZ economist David Plank cited political uncertainty as the main catalyst. The sub-index for future household finances fell to its lowest level of the year. More »',
#    'url': 'https://www.businessinsider.com.au/political-uncertainty-just-sent-a-key-measure-of-australian-household-confidence-to-its-lowest-level-of-the-year-2018-8',
#    'urlToImage': 'https://edge.alluremedia.com.au/uploads/businessinsider/2018/08/turnbull-640x360.jpg',
#    'publishedAt': '2018-08-20T15:13:47Z'},
#   {'source': {'id': None, 'name': 'Hospitalitynet.org'},
#    'author': 'Laura Zizka',
#    'title': 'How to Foster Positive Change in a Shifting Cultural Landscape | By Laura Zizka',
#    'description': "At an international conference on knowledge, culture, and change in organizations held recently in Germany, Dr Peter Kell, University Professorial Fellow from Charles Darwin University in Australia, spoke in a keynote about change being 'ubiquitous' and about…",
#    'url': 'https://www.hospitalitynet.org/opinion/4089657.html',
#    'urlToImage': 'https://www.hospitalitynet.org/picture/a_153072944.jpg',
#    'publishedAt': '2018-08-20T13:10:57Z'},
#   {'source': {'id': None, 'name': 'Azcentral.com'},
#    'author': 'Arizona Republic, Rachel Leingang, Arizona Republic',
#    'title': 'Arizona universities seeing fewer international students attending, reversing trend',
#    'description': 'After years of steady increases in the number of international students, Arizona State University and the University of Arizona are seeing declines.',
#    'url': 'https://www.azcentral.com/story/news/local/arizona-education/2018/08/20/number-international-students-declines-arizona-colleges-asu-ua/630930002/?utm_source=google&utm_medium=amp&utm_campaign=speakable',
#    'urlToImage': 'https://www.gannett-cdn.com/presto/2018/08/17/PPHX/1d13cdc7-3c79-45be-a2e8-971877dbda65-_E1_5675.jpg?crop=4040,2273,x0,y244&width=3200&height=1680&fit=bounds',
#    'publishedAt': '2018-08-20T13:00:01Z'},
#   {'source': {'id': 'independent', 'name': 'Independent'},
#    'author': 'Harry Cockburn, Harry Cockburn',
#    'title': 'Australia pulls out of climate change targets agreed at Paris conference',
#    'description': "'Cheaper power has always been our number one priority'",
#    'url': 'https://www.independent.co.uk/news/world/australasia/australia-climate-change-malcolm-turnbull-prime-minister-leadership-a8499366.html',
#    'urlToImage': 'https://static.independent.co.uk/s3fs-public/thumbnails/image/2018/08/20/13/Australia-bush-fire.jpg',
#    'publishedAt': '2018-08-20T12:59:38Z'},
#   {'source': {'id': None, 'name': 'Scmp.com'},
#    'author': 'Cheng-Chwee Kuik, Chin Tong Liew, Cheng-Chwee Kuik, Chin Tong Liew',
#    'title': 'What Malaysia’s ‘Mahathir doctrine’ means for China-US rivalry',
#    'description': 'Since returning to power after his stunning election victory in May, 93-year-old Malaysian Prime Minister Mahathir Mohamad has made a series of comments reflective of weaker states’ views of the evolving Asian order in the Trump-Xi era. These include a firmer…',
#    'url': 'https://www.scmp.com/week-asia/geopolitics/article/2160552/what-malaysias-mahathir-doctrine-means-china-us-rivalry',
#    'urlToImage': 'https://cdn2.i-scmp.com/sites/default/files/styles/og_image_scmp_generic/public/images/methode/2018/08/20/7eeadda0-a466-11e8-851a-8c4276191601_image_hires_204946.JPG?itok=qVWROlf2',
#    'publishedAt': '2018-08-20T12:45:00Z'},
#   {'source': {'id': 'the-telegraph', 'name': 'The Telegraph'},
#    'author': 'Our Foreign Staff',
#    'title': 'Australian PM Malcolm Turnbull ditches key climate policy to stave off leadership revolt',
#    'description': 'Malcolm Turnbull, the Australian prime minister, on Monday averted a possible leadership challenge by dropping targets for cutting greenhouse gas emissions to appease his critics, as a poll showed support for his government slipping.',
#    'url': 'https://www.telegraph.co.uk/news/2018/08/20/australian-pm-malcolm-turnbull-ditches-key-climate-policy-stave/',
#    'urlToImage': 'https://www.telegraph.co.uk/content/dam/news/2018/08/20/TELEMMGLPICT000172037438-xlarge_trans_NvBQzQNjv4BqM37qcIWR9CtrqmiMdQVx7Ji2t92DiMJ6H_xG_w4k0Vk.jpeg',
#    'publishedAt': '2018-08-20T12:37:43Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Elise Scott',
#    'title': "A $280k apology: Liberal MLA's sledge on union boss leaves taxpayers footing the bill",
#    'description': 'Taxpayers in the ACT will be slugged with a $280,000 legal bill on behalf of Liberal MLA and former opposition leader Jeremy Hanson, after he settled a defamation case brought by former CFMEU boss Dean Hall.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/jeremy-hanson-dean-hall-union-defamation-settle/10144872',
#    'urlToImage': 'http://www.abc.net.au/news/image/10143940-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T12:30:23Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Christopher Woody',
#    'title': 'Germany wants a new nuclear-capable fighter, and the US may get a say about which one',
#    'description': 'Germany wants to replace its fleet of 89 Tornado combat jets with a new aircraft that retains the plane’s nuclear capability, but doing so may mean the US gets a say about which aircraft the Luftwaffe ultimately picks, according to Defence News.',
#    'url': 'https://www.businessinsider.com.au/us-may-influence-new-german-fighter-aircraft-over-nuclear-capability-2018-8',
#    'urlToImage': 'https://static.businessinsider.com/image/5b34e8b3c60fa41c008b462b-640.jpg',
#    'publishedAt': '2018-08-20T11:33:51Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Sonam Sheth, Grace Panetta',
#    'title': 'Trump targeted Mueller in his most direct attack yet, and experts say his comments could impact the Manafort trial',
#    'description': 'President Donald Trump went after the special counsel Robert Mueller on Monday in his most direct attack yet on the former FBI director. He called Mueller "disgraced and discredited," and referred to his team of prosecutors as "thugs" who enjoy "ruining peopl…',
#    'url': 'https://www.businessinsider.com.au/trump-targets-mueller-direct-attack-special-counsel-2018-8',
#    'urlToImage': 'https://edge.alluremedia.com.au/uploads/businessinsider/2018/07/trump-letterbox-640x360.jpg',
#    'publishedAt': '2018-08-20T11:02:25Z'},
#   {'source': {'id': 'independent', 'name': 'Independent'},
#    'author': 'Maya Oppenheim, Maya Oppenheim',
#    'title': "New Zealand women's minister cycles to hospital to give birth to first child",
#    'description': "'My partner and I cycled because there wasn't enough room in the car for the support crew... but it also put me in the best possible mood!' says Julie Anne Genter",
#    'url': 'https://www.independent.co.uk/news/world/australasia/julie-anne-genter-new-zealand-minister-women-cycles-birth-hospital-jacinda-ardern-a8499131.html',
#    'urlToImage': 'https://static.independent.co.uk/s3fs-public/thumbnails/image/2018/08/20/11/anne-0.png',
#    'publishedAt': '2018-08-20T11:01:57Z'},
#   {'source': {'id': None, 'name': 'Inquirer.net'},
#    'author': 'eestopace',
#    'title': 'Tourists go off beaten path on North Korea’s sacred volcano',
#    'description': "Foreign tourists looking to go off the beaten path in North Korea can now camp out on the country's biggest volcano. The post Tourists go off beaten path on North Korea’s sacred volcano appeared first on Inquirer News.",
#    'url': 'http://newsinfo.inquirer.net/1023270/tourists-go-off-beaten-path-on-north-koreas-sacred-volcano',
#    'urlToImage': 'http://newsinfo.inquirer.net/wp-content/blogs.dir/10/files/2018/08/AP18231163116954-620x414.jpg',
#    'publishedAt': '2018-08-20T10:59:02Z'},
#   {'source': {'id': None, 'name': 'Theage.com.au'},
#    'author': None,
#    'title': 'Lamentable power play not in the public interest',
#    'description': 'The main message of 21st-century Australian politics is strife is worsened, not quashed, by parties dumping sitting prime ministers.',
#    'url': 'https://www.theage.com.au/national/lamentable-power-play-not-in-the-public-interest-20180820-p4zyml.html',
#    'urlToImage': 'https://static.ffx.io/images/$zoom_1.0347,$multiply_0.7554296506137866,$ratio_1.777778,$width_1059,$x_0,$y_26/t_crop_custom/t_sharpen,q_auto,f_auto/0bee40554b762d6426b4edf58ae66b251366315a',
#    'publishedAt': '2018-08-20T10:09:01Z'},
#   {'source': {'id': 'politico', 'name': 'Politico'},
#    'author': 'daniel@politico.com (Daniel Lippman)',
#    'title': 'POLITICO Playbook: Scoop: Ivanka, Jared are headlining Ryan’s Jackson Hole donor retreat',
#    'description': 'And shots are fired at the gate of the U.S. Embassy in Turkey.',
#    'url': 'https://www.politico.com/newsletters/playbook/2018/08/20/scoop-ivanka-jared-are-headlining-ryans-jackson-hole-donor-retreat-299392',
#    'urlToImage': 'https://static.politico.com/6b/c4/c4d9aca74ea192bac17ac53cd6e4/ap-18211003808109.jpg',
#    'publishedAt': '2018-08-20T10:08:58Z'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'Rachel Pannett',
#    'title': "Divisions on Climate Policy Threaten Australia's Turnbull",
#    'description': 'Australia’s prime minister, facing a rebellion within his conservative ranks, backed away from attempts to mandate emissions-reduction targets in a bid to save his leadership.',
#    'url': 'https://www.wsj.com/articles/divisions-on-climate-policy-threaten-australias-turnbull-1534754503',
#    'urlToImage': 'https://images.wsj.net/im-22748/social',
#    'publishedAt': '2018-08-20T09:05:51Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Rebecca Puddy',
#    'title': "Shipbuilders out of work as industry slides further into 'valley of death'",
#    'description': 'Shipbuilder ASC is poised to shed a further 93 jobs from its Adelaide shipyard as the last Air Warfare Destroyer nears completion.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/adelaide-shipbuilders-out-of-work-93-jobs/10143956',
#    'urlToImage': 'http://www.abc.net.au/news/image/7227038-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T08:55:20Z'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Colin Packham and Erin Cooper',
#    'title': 'Australia weakens commitment to climate accord after government fractures',
#    'description': 'Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centrepiece energy policy in the face of political opposition, although the country remains a signatory to the Paris Agreement.',
#    'url': 'https://af.reuters.com/article/worldNews/idAFKCN1L50EF',
#    'urlToImage': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20180820&t=2&i=1295469116&w=1200&r=LYNXNPEE7J0EB',
#    'publishedAt': '2018-08-20T08:54:20Z'},
#   {'source': {'id': 'the-irish-times', 'name': 'The Irish Times'},
#    'author': 'Jamie Smyth',
#    'title': 'Australia’s Malcolm Turnbull shelves flagship energy policy',
#    'description': 'PM dumps emissions targets in bid to stave off leadership challenge in Liberal party',
#    'url': 'https://www.irishtimes.com/news/world/asia-pacific/australia-s-malcolm-turnbull-shelves-flagship-energy-policy-1.3601819',
#    'urlToImage': 'https://www.irishtimes.com/image-creator/?id=1.3601817&origw=1440',
#    'publishedAt': '2018-08-20T08:11:00Z'},
#   {'source': {'id': None, 'name': 'Smh.com.au'},
#    'author': 'Geoffrey Stokes',
#    'title': 'What are we to make of Fraser Anning’s maiden speech?',
#    'description': 'It is vital to step back from the outrage and understand Anning’s speech as part of a longer trajectory of Australian populism.',
#    'url': 'https://www.smh.com.au/national/what-are-we-to-make-of-fraser-anning-s-maiden-speech-20180819-p4zyfk.html',
#    'urlToImage': 'https://static.ffx.io/images/$zoom_0.5109,$multiply_0.7554296506137866,$ratio_1.777778,$width_1059,$x_623,$y_0/t_crop_custom/t_sharpen,q_auto,f_auto/2575c9460810b7b9868f9972d3e6124eaf605008',
#    'publishedAt': '2018-08-20T08:02:01Z'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Erin Cooper',
#    'title': 'Australian PM waters down energy bill to dampen leadership pressure - Reuters',
#    'description': 'Reuters Australian PM waters down energy bill to dampen leadership pressure Reuters SYDNEY (Reuters) - Australian Prime Minister Malcolm Turnbull on Monday averted a possible leadership challenge by dropping targets for cutting greenhouse gas emissions to app…',
#    'url': 'https://uk.reuters.com/article/uk-australia-politics/australian-pm-under-pressure-as-voter-support-slides-idUKKCN1L40RB',
#    'urlToImage': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20180819&t=2&i=1295378836&w=1200&r=LYNXNPEE7I0L3',
#    'publishedAt': '2018-08-20T07:43:19Z'},
#   {'source': {'id': 'daily-mail', 'name': 'Daily Mail'},
#    'author': 'http://www.dailymail.co.uk/home/search.html?s=&authornamef=Reuters',
#    'title': 'Australian PM waters down energy bill to dampen...',
#    'description': 'By Erin CooperSYDNEY, Aug 20 (Reuters) - Australian Prime Minister Malcolm  Turnbull on Monday averted a possible leadership challenge by  dropping targets...',
#    'url': 'http://www.dailymail.co.uk/wires/reuters/article-6077957/Australian-PM-waters-energy-bill-dampen-leadership-pressure.html',
#    'urlToImage': 'https://i.dailymail.co.uk/i/pix/m_logo_636x382px.png',
#    'publishedAt': '2018-08-20T07:39:18Z'},
#   {'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#    'author': 'Damien Cave',
#    'title': 'Australian Prime Minister Abandons Climate Targets, Bowing to Party Pressure',
#    'description': 'On Monday, Malcolm Turnbull announced he would delay a climate and energy policy that divided senior figures in the Australian government.',
#    'url': 'https://www.nytimes.com/2018/08/20/world/australia/turnbull-energy-emissions-climate-change.html',
#    'urlToImage': 'https://static01.nyt.com/images/2018/08/21/world/21oz-emissions-1/21oz-emissions-1-facebookJumbo.jpg',
#    'publishedAt': '2018-08-20T07:30:43Z'},
#   {'source': {'id': None, 'name': 'Wattsupwiththat.com'},
#    'author': 'Anthony Watts',
#    'title': 'Weekly Climate and Energy News Roundup',
#    'description': 'Brought to You by SEPP (www.SEPP.org) The Science and Environmental Policy Project THIS WEEK: By Ken Haapala, President, Science and Environmental Policy Project (SEPP) Transparency in Regulatory Science: On August 16, the EPA comment period closed on propose…',
#    'url': 'https://wattsupwiththat.com/2018/08/20/weekly-climate-and-energy-news-roundup-326/',
#    'urlToImage': 'https://4k4oijnpiu3l4c3h-zippykid.netdna-ssl.com/wp-content/uploads/2014/08/sepp_logo_onclouds.jpg',
#    'publishedAt': '2018-08-20T07:23:49Z'},
#   {'source': {'id': None, 'name': 'Allafrica.com'},
#    'author': '',
#    'title': 'How Electoral Democracy Hurts the Collective Cause',
#    'description': '[The Herald] Something is going wrong with democracy. Something has gone wrong with democracy. It was the most successful political idea of the 21st century, but increasingly democracy is running into trouble, not least because there are people who confuse de…',
#    'url': 'https://allafrica.com/stories/201808200104.html',
#    'urlToImage': 'http://allafrica.com/static/images/structure/aa-logo-rgba-no-text-128x128.png',
#    'publishedAt': '2018-08-20T07:20:50Z'},
#   {'source': {'id': None, 'name': 'Hoover.org'},
#    'author': None,
#    'title': 'Russia, China, and the Future of Democracy',
#    'description': 'Image credit: Uncommon Knowledge Blank Section (Placeholder) Featured interview with Toomas Hendrik Ilves Nick Clegg Anders Fogh Rasmussen Felipe Calderón via Uncommon Knowledge Hoover Daily Report Analyzing the future of democracy with former prime ministers…',
#    'url': 'https://www.hoover.org/research/russia-china-and-future-democracy',
#    'urlToImage': 'https://www.hoover.org/sites/default/files/research/images/2018-08-17_14-19-58.png',
#    'publishedAt': '2018-08-20T07:16:00Z'},
#   {'source': {'id': None, 'name': 'Moneycontrol.com'},
#    'author': None,
#    'title': 'Australia weakens commitment to climate accord after government fractures',
#    'description': 'Turnbull added that his government would move legislation to reduce emissions when it had sufficient support from its own party. Despite the impasse, Turnbull said the government was committed to its Paris accord commitments.',
#    'url': 'https://www.moneycontrol.com/news/world/australia-weakens-commitment-to-climate-accord-after-government-fractures-2860451.html',
#    'urlToImage': 'https://static-news.moneycontrol.com/static-mcnews/2018/08/9bafc6551bc222f468bd078592513777-770x433.jpg',
#    'publishedAt': '2018-08-20T07:15:13Z'},
#   {'source': {'id': None, 'name': 'Nzherald.co.nz'},
#    'author': 'newsfeeds@nzherald.co.nz',
#    'title': 'Jacinda Ardern turns up heat over asylum seekers as Peters heads to Canberra in the midst of political turmoil',
#    'description': 'Foreign Minister Winston Peters is heading to Canberra on Tuesday for talks with his counterpart where two sensitive issues are expected to be raised: detention of New Zealanders without charge, and offshore asylum seekers.Peters...',
#    'url': 'https://www.nzherald.co.nz/nz/news/article.cfm?c_id=1&objectid=12110373',
#    'urlToImage': 'https://www.nzherald.co.nz/resizer/9ZVX0Iryy7B-221p5Z9NbTBIJwU=/1200x0/smart/filters:quality(70)/arc-anglerfish-syd-prod-nzme.s3.amazonaws.com/public/3DQD56V5RZE5NACRRWBWHVEMTM.jpg',
#    'publishedAt': '2018-08-20T07:14:34Z'},
#   {'source': {'id': None, 'name': 'Silodrome.com'},
#    'author': 'Ben Branch',
#    'title': 'Ayrton Senna’s Last Kart – He Drove It Weeks Before His Death – £50,000 to £70,000',
#    'description': 'Ayrton Senna’s Last Kart – He Drove It Weeks Before His Death – £50,000 to £70,000 This is the last kart ever driven by Ayrton Senna, he piloted around his personal go kart track on his farm in the town of Tatui in the state of São Paulo, Brazil on the 19th o…',
#    'url': 'https://silodrome.com/ayrton-sennas-last-kart/',
#    'urlToImage': 'https://silodrome.com/wp-content/uploads/2018/08/Ayrton-Senna-Go-Kart-Main.jpg',
#    'publishedAt': '2018-08-20T07:01:55Z'},
#   {'source': {'id': 'financial-times', 'name': 'Financial Times'},
#    'author': None,
#    'title': 'Australia’s Malcolm Turnbull shelves flagship energy policy',
#    'description': 'Prime minister backtracks on legislating emissions targets as political rivals circle',
#    'url': 'https://www.ft.com/content/1650bd14-a425-11e8-8ecf-a7ae1beff35b',
#    'urlToImage': 'https://www.ft.com/__origami/service/image/v2/images/raw/http%3A%2F%2Fprod-upp-image-read.ft.com%2F8248fe98-9ece-11e8-b196-da9d6c239ca8?source=next-opengraph&fit=scale-down&width=900',
#    'publishedAt': '2018-08-20T06:41:25Z'},
#   {'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'author': 'Christopher Knaus in Canberra',
#    'title': 'Australian PM dumps key climate policy to stave off leadership revolt',
#    'description': 'Malcolm Turnbull gives in to conservative members of his party who demanded he axe carbon emission reduction targets Australia’s prime minister has abandoned plans to rein in greenhouse gas emissions in an attempt to stave off a leadership coup from within hi…',
#    'url': 'https://www.theguardian.com/australia-news/2018/aug/20/australian-pm-dumps-key-climate-policy-to-stave-off-leadership-revolt',
#    'urlToImage': 'https://i.guim.co.uk/img/media/1734dd0eb9833fb2f45f8524f5e7a904f5f63a22/0_195_5568_3342/master/5568.jpg?w=1200&h=630&q=55&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=ac1f22f52f7b40159e3466295882e512',
#    'publishedAt': '2018-08-20T06:25:20Z'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Colin Packham',
#    'title': 'Australia weakens commitment to climate accord after government fractures - Reuters',
#    'description': 'Reuters Australia weakens commitment to climate accord after government fractures Reuters SYDNEY (Reuters) - Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centerpiece energy policy in the…',
#    'url': 'https://uk.reuters.com/article/uk-climatechange-accord-australia/australia-weakens-commitment-to-climate-accord-after-government-fractures-idUKKCN1L50EF',
#    'urlToImage': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20180820&t=2&i=1295469116&w=1200&r=LYNXNPEE7J0EB',
#    'publishedAt': '2018-08-20T06:11:08Z'},
#   {'source': {'id': None, 'name': 'Channelnewsasia.com'},
#    'author': None,
#    'title': 'Australia weakens commitment to climate accord after government fractures',
#    'description': 'Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centrepiece energy policy in the face of political opposition, although the country remains a signatory to the Paris Agreement.',
#    'url': 'https://www.channelnewsasia.com/news/world/australia-weakens-commitment-to-climate-accord-after-government-fractures-10633562',
#    'urlToImage': 'http://www.channelnewsasia.com/image/10633558/16x9/991/529/ce6ff110e01751f08e4e8c569a17233c/gb/australian-prime-minister-malcolm-turnbull-speaks-to-the-media-in-sydney-1.jpg',
#    'publishedAt': '2018-08-20T06:10:19Z'},
#   {'source': {'id': None, 'name': 'Thestar.com.my'},
#    'author': 'By Colin Packham and Erin Cooper',
#    'title': 'Australia weakens commitment to climate accord after government fractures',
#    'description': 'SYDNEY (Reuters) - Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centrepiece energy policy in the face of political opposition, although the country remains a signatory to the Paris Agree…',
#    'url': 'http://www.thestar.com.my/news/world/2018/08/20/australia-weakens-commitment-to-climate-accord-after-government-fractures/',
#    'urlToImage': 'https://www.thestar.com.my/~/media/online/2018/08/20/06/07/20180820t060157z_1_lynxnpee7j0eb_rtroptp_4_australiapolitics.ashx/?w=620&h=413&crop=1&hash=F8594967712AC5A3A130DDCD366013211E9E8604',
#    'publishedAt': '2018-08-20T06:07:02Z'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Colin Packham',
#    'title': 'Australia weakens commitment to climate accord after government fractures - Reuters',
#    'description': 'Reuters Australia weakens commitment to climate accord after government fractures Reuters SYDNEY (Reuters) - Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centrepiece energy policy in the…',
#    'url': 'https://uk.reuters.com/article/us-climatechange-accord-australia/australia-waters-down-commitment-to-climate-accord-amid-domestic-political-fight-idUKKCN1L507Y',
#    'urlToImage': 'https://s4.reutersmedia.net/resources/r/?m=02&d=20180820&t=2&i=1295441383&w=1200&r=LYNXNPEE7J08W',
#    'publishedAt': '2018-08-20T06:07:00Z'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Colin Packham',
#    'title': 'Australia weakens commitment to climate accord after government fractures',
#    'description': 'Australian Prime Minister Malcolm Turnbull on Monday stripped requirements for reducing greenhouse emissions from his centerpiece energy policy in the face of political opposition, although the country remains a signatory to the Paris Agreement.',
#    'url': 'https://www.reuters.com/article/us-climatechange-accord-australia/australia-waters-down-commitment-to-climate-accord-amid-domestic-political-fight-idUSKCN1L507Y',
#    'urlToImage': 'https://s4.reutersmedia.net/resources/r/?m=02&d=20180820&t=2&i=1295441383&w=1200&r=LYNXNPEE7J08W',
#    'publishedAt': '2018-08-20T06:00:07Z'},
#   {'source': {'id': 'daily-mail', 'name': 'Daily Mail'},
#    'author': 'http://www.dailymail.co.uk/home/search.html?s=&authornamef=Reuters',
#    'title': 'Australia weakens commitment to climate accord after...',
#    'description': 'By Colin Packham and Erin CooperSYDNEY, Aug 20 (Reuters) - Australian Prime Minister Malcolm  Turnbull on Monday stripped requirements for reducing...',
#    'url': 'http://www.dailymail.co.uk/wires/reuters/article-6077737/Australia-weakens-commitment-climate-accord-government-fractures.html',
#    'urlToImage': 'https://i.dailymail.co.uk/i/pix/m_logo_636x382px.png',
#    'publishedAt': '2018-08-20T05:59:16Z'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Malcolm Turnbull: Under-pressure Australia PM drops climate policy',
#    'description': "Malcolm Turnbull's decision to drop an emissions target follows a revolt within his government.",
#    'url': 'https://www.bbc.co.uk/news/world-australia-45242806',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/C75E/production/_103083015_gettyimages-637955734.jpg',
#    'publishedAt': '2018-08-20T05:53:40Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Travis Clark',
#    'title': "Chelsea Handler defended former senator Al Franken by saying groping is 'not sexual assault'",
#    'description': "Comedian Chelsea Handler came to former senator Al Franken's defence in an interview with Profile by Buzzfeed News. Franken resigned in January after multiple women accused him of groping and unwanted advances. More »",
#    'url': 'https://www.businessinsider.com.au/chelsea-handler-says-groping-not-sexual-assault-defends-al-franken-2018-8',
#    'urlToImage': 'https://static.businessinsider.com/image/59e8a42eddd0631c1e8b510f-640.jpg',
#    'publishedAt': '2018-08-20T05:52:27Z'},
#   {'source': {'id': None, 'name': 'Americanthinker.com'},
#    'author': None,
#    'title': 'Australian PM drops climate change policy',
#    'description': 'In trouble with his own Liberal Party, Malcolm Turnbull yields to political reality.',
#    'url': 'https://www.americanthinker.com/blog/2018/08/australian_pm_drops_climate_change_policy.html',
#    'urlToImage': 'https://www.americanthinker.com/images/bucket/2018-08/208524.jpg',
#    'publishedAt': '2018-08-20T05:00:00Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Eliza Laschon',
#    'title': 'Health Department bureaucrats pursued for repayments after corruption exposed',
#    'description': 'Three former WA Health Department officials implicated in a decade-long corruption scandal are issued notices demanding they pay back their redundancy payouts and any money and gifts allegedly fraudulently obtained.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/health-officials-pursued-for-repayments-after-corruption-exposed/10139850',
#    'urlToImage': 'http://www.abc.net.au/news/image/10128316-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T04:46:21Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'http://www.abc.net.au/news/jackson-gothe-snape/8998150',
#    'title': "Confused about Malcolm Turnbull's leadership crisis? Here's what you need to know - ABC News",
#    'description': "ABC News Confused about Malcolm Turnbull's leadership crisis? Here's what you need to know ABC News Less than a week after securing his party's support for a new energy policy, Malcolm Turnbull's leadership is under intense scrutiny. Key points: Malcolm Turnb…",
#    'url': 'http://www.abc.net.au/news/2018-08-20/malcom-turnbull-leadership-crisis-explained/10139208',
#    'urlToImage': 'http://www.abc.net.au/news/image/10142896-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T04:39:37Z'},
#   {'source': {'id': None, 'name': 'Bbc.com'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Malcolm Turnbull: Under-pressure Australia PM drops climate policy - BBC News',
#    'description': 'BBC News Malcolm Turnbull: Under-pressure Australia PM drops climate policy BBC News Hywel Griffith, BBC News Sydney correspondent. Down in the polls and desperate to hold on to his position, Malcolm Turnbull knows a leadership challenge could be near. After …',
#    'url': 'https://www.bbc.com/news/world-australia-45242806',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/C75E/production/_103083015_gettyimages-637955734.jpg',
#    'publishedAt': '2018-08-20T03:46:44Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': "'We are bloody short': Victorian farmers battling through 'green drought'",
#    'description': 'Eastern Victorian farmland may look relatively lush, but the paddocks are bare and the cattle are hungry, prompting farmers to plead with governments not to ignore them.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/east-gippsland-farmers-battle-green-drought/10139312',
#    'urlToImage': 'http://www.abc.net.au/news/image/10139762-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T03:29:07Z'},
#   {'source': {'id': 'daily-mail', 'name': 'Daily Mail'},
#    'author': 'http://www.dailymail.co.uk/home/search.html?s=&authornamef=Chloe-lee+Longhetti+For+Daily+Mail+Australia',
#    'title': "Fans praise controversial former politician Sam Dastyari's new TV show Disgrace!",
#    'description': "Fans flocked to Twitter on Sunday night to praise controversial politician Sam Dastyari's new TV show, Disgrace!",
#    'url': 'http://www.dailymail.co.uk/tvshowbiz/article-6077183/Fans-praise-controversial-former-politician-Sam-Dastyaris-new-TV-Disgrace.html',
#    'urlToImage': 'https://i.dailymail.co.uk/i/newpix/2018/08/20/02/4F39ECB700000578-0-image-a-28_1534729064212.jpg',
#    'publishedAt': '2018-08-20T02:58:59Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': 'NSW Government directs $72m to homes and businesses to reduce energy costs',
#    'description': 'The NSW Government is taking $72 million from its Climate Change Fund to help some businesses and low-income renters reduce their energy costs, but an environmental group says the state is "buying water pistols" to douse a fire.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/nsw-government-plan-reduce-energy-costs/10139686',
#    'urlToImage': 'http://www.abc.net.au/news/image/9135008-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T02:57:08Z'},
#   {'source': {'id': None, 'name': 'Livejournal.com'},
#    'author': 'badtz_m',
#    'title': "ONTD Original: A Brief Look At Lady Gaga's Year In 2008",
#    'description': "ONTD Original: A Brief Look At Lady Gaga's Year In 2008 Today (August 19th) marks the 10th anniversary of the breakout album that had critics predicting Lady Gaga was the future of pop - and they predicted right. Recording sessions for this album overlapped w…",
#    'url': 'https://ohnotheydidnt.livejournal.com/112035963.html',
#    'urlToImage': 'https://l-files.livejournal.net/og_image/3616053/437640?v=1534733215',
#    'publishedAt': '2018-08-20T02:46:47Z'},
#   {'source': {'id': None, 'name': 'Theconversation.com'},
#    'author': 'Michelle Grattan, Professorial Fellow, University of Canberra',
#    'title': 'Malcolm Turnbull shelves emissions reduction target as leadership speculation mounts',
#    'description': 'The prime minister has capitulated on his controversial energy policy in an attempt to quell the ring-wing uprising within his party.',
#    'url': 'http://theconversation.com/malcolm-turnbull-shelves-emissions-reduction-target-as-leadership-speculation-mounts-101811',
#    'urlToImage': 'https://images.theconversation.com/files/232607/original/file-20180820-30593-87nest.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1356&h=668&fit=crop',
#    'publishedAt': '2018-08-20T02:21:15Z'},
#   {'source': {'id': 'daily-mail', 'name': 'Daily Mail'},
#    'author': 'http://www.dailymail.co.uk/home/search.html?s=&authornamef=Associated+Press',
#    'title': "Tourists go off beaten path on North Korea's sacred...",
#    'description': "MOUNT PAEKTU, North Korea (AP) - Foreign tourists looking to go off the beaten path in North Korea can now camp out on the country's biggest volcano.Hoping...",
#    'url': 'http://www.dailymail.co.uk/wires/ap/article-6077309/headline-Tourists-beaten-path-North-Koreas-sacred-volcano.html',
#    'urlToImage': 'https://i.dailymail.co.uk/1s/2018/08/20/03/wire-4008382-1534731570-176_636x382.jpg',
#    'publishedAt': '2018-08-20T02:20:18Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'http://www.abc.net.au/news/andrew-probyn/8259322',
#    'title': "Analysis: Turnbull's opponents are waging a guerilla war to kill off his leadership",
#    'description': "Six days after triumphantly walking into the Prime Minister's courtyard having navigated his energy policy through the hostilities of his coalition partyroom, Malcolm Turnbull is on the precipice, writes Andrew Probyn.",
#    'url': 'http://www.abc.net.au/news/2018-08-20/malcolm-turnbull-facing-guerilla-warfare/10139276',
#    'urlToImage': 'http://www.abc.net.au/news/image/10133906-16x9-700x394.jpg',
#    'publishedAt': '2018-08-20T00:56:49Z'},
#   {'source': {'id': None, 'name': 'Mumbrella.com.au'},
#    'author': 'Abigail Dawson',
#    'title': 'TBWA Sydney embroiled in legal battle with former employee over bullying and harassment claims',
#    'description': 'TBWA Sydney is tied up in a legal battle after a former planning director filed documents in the Federal Circuit Court of Australia claiming she was fired for lodging bullying and harassment claims against the ad agency’s Sydney managing director. TBWA strong…',
#    'url': 'https://mumbrella.com.au/tbwa-sydney-embroiled-in-legal-battle-with-former-employee-over-bullying-and-harassment-claims-536089',
#    'urlToImage': 'https://mumbrella.com.au/wp-content/uploads/2018/08/tbwa-2.png',
#    'publishedAt': '2018-08-20T00:25:41Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Matt Liddy',
#    'title': 'Chart of the day: Where do migrants to Australia come from?',
# ...
#    'description': "A Tasmanian MP calls for code of conduct complaints against ministers to be dealt with independently, after the state's Health Minister was cleared of any breach following his admission he discussed a Cricket Australia employee's abortion before she was sacke…",
#    'url': 'http://www.abc.net.au/news/2018-08-20/angela-williamson-saga-expected-to-dominate-return-of-parliament/10138704',
#    'urlToImage': 'http://www.abc.net.au/news/image/10055378-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T21:03:14Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Richard Willingham',
#    'title': 'Victorian Greens push for banks to pay more with controversial levy',
#    'description': 'A bold proposal for a bank levy — similar to one dumped by South Australia — has been put forward by the Victorian Greens ahead of the state election, which if backed could raise $1.5 billion for the state.',
#    'url': 'http://www.abc.net.au/news/2018-08-20/victorian-greens-propose-bank-levy-ahead-of-state-election/10134508',
#    'urlToImage': 'http://www.abc.net.au/radionational/image/6985068-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T20:28:17Z'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'James Rainey',
#    'title': 'Scientists bolder in blaming global warming for extreme weather',
#    'description': "Researchers no longer hesitate to blame climate change for floods, fires and heat waves. Here's how the science works.",
#    'url': 'https://www.nbcnews.com/news/us-news/global-warming-can-make-extreme-weather-worse-now-scientists-can-n901751?cid=public-rss_20180821',
#    'urlToImage': None,
#    'publishedAt': '2018-08-19T20:27:48Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Kirrin McKechnie',
#    'title': "Inner-Brisbane schools 'bursting at seams' as development booms",
#    'description': "Libraries are being used as classrooms and demountables are being built on ovals. The development boom in inner-Brisbane has caused massive overcrowding problems in local state schools and the government is not keeping up, Queensland's only Greens MP says.",
#    'url': 'http://www.abc.net.au/news/2018-08-20/brisbane-schools-overcrowded-as-development-booms/10137628',
#    'urlToImage': 'http://www.abc.net.au/news/image/10137626-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T19:56:27Z'},
#   {'source': {'id': 'australian-financial-review',
#     'name': 'Australian Financial Review'},
#    'author': 'Matthew Stevens',
#    'title': "Dark view of business: Australia's energy policy in a race to the bottom",
#    'description': 'We are watching a race to the bottom in energy market policy that apparently has a Liberal prime minister contemplating some form of electricity market re-regulation.',
#    'url': 'https://www.afr.com/business/energy/electricity/dark-view-of-business-australias-energy-policy-in-a-race-to-the-bottom-20180819-h1467l',
#    'urlToImage': 'https://www.afr.com/content/dam/images/h/1/4/5/f/h/image.related.socialLead.620x349.h1467l.png/1534668403123.jpg',
#    'publishedAt': '2018-08-19T19:30:20Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Stephen Dziedzic',
#    'title': "'Exceedingly grateful': Tonga's sudden change of heart on Chinese loans",
#    'description': "Last week Tonga's Prime Minister was calling on Pacific Island leaders to band together and press China at an upcoming forum to write off their debts, but now he says that's not a good idea.",
#    'url': 'http://www.abc.net.au/news/2018-08-20/tonga-prime-minister-changes-mind-on-china-loan-issue/10138068',
#    'urlToImage': 'http://www.abc.net.au/news/image/10138192-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T19:22:06Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Paul Colgan',
#    'title': 'CAPITULATION...',
#    'description': 'Malcolm Turnbull has announced another change in energy policy, ditching plans to introduce legislation designed to ensure Australia meets its commitments to emission reductions under the Paris Agreement. More »',
#    'url': 'https://www.businessinsider.com.au/malcolm-turnbull-leadership-paris-agreement-emissions-targets-2018-8',
#    'urlToImage': 'https://edge.alluremedia.com.au/uploads/businessinsider/2017/03/Malcolm-Turnbull-black-background-640x360.jpg',
#    'publishedAt': '2018-08-19T15:49:48Z'},
#   {'source': {'id': None, 'name': 'Globalresearch.ca'},
#    'author': 'James M. Dorsey',
#    'title': 'Turkey’s Financial Crisis Raises Questions About China’s Debt-driven Development Model',
#    'description': 'Note to readers: please click the share buttons above Financial injections by Qatar and possibly China may resolve Turkey’s immediate economic crisis, aggravated by a politics-driven trade war with the United States, but are unlikely to resolve the country’s …',
#    'url': 'https://www.globalresearch.ca/turkeys-financial-crisis-raises-questions-about-chinas-debt-driven-development-model/5651129',
#    'urlToImage': None,
#    'publishedAt': '2018-08-19T13:50:55Z'},
#   {'source': {'id': None, 'name': 'Sport360.com'},
#    'author': 'Sport 360',
#    'title': 'Former India batsman Gautam Gambhir reportedly set to enter the field of politics - Sport360',
#    'description': 'Sport360 Former India batsman Gautam Gambhir reportedly set to enter the field of politics Sport360 Even as former Pakistan skipper Imran Khan took oath as the newly elected Prime Minister of the country on Saturday, the trend of cricketers turning to politic…',
#    'url': 'http://sport360.com/article/cricket/international-cricket/299111/former-india-batsman-gautam-gambhir-reportedly-set-to-enter-the-field-of-politics/',
#    'urlToImage': 'http://sport360.com/wp-content/uploads/2018/08/GAMBHIR.jpg',
#    'publishedAt': '2018-08-19T13:00:28Z'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'James Rainey',
#    'title': 'Scientists bolder in blaming global warming for extreme weather',
#    'description': "After years of hesitation, scientists are blaming global warming more forcefully, and quickly, for extreme weather events like heat waves and droughts. Here's how the science works.",
#    'url': 'https://www.nbcnews.com/news/us-news/global-warming-can-make-extreme-weather-worse-now-scientists-can-n901751',
#    'urlToImage': 'https://media1.s-nbcnews.com/j/newscms/2018_31/2514846/180730-japan-flood-ac-1056p_0be348122af0101e78d01be33ba2c127.1200;630;7;70;5.jpg',
#    'publishedAt': '2018-08-19T09:55:15Z'},
#   {'source': {'id': None, 'name': 'Freemalaysiatoday.com'},
#    'author': 'FMT Reporters',
#    'title': 'Aviation expert slams MH370 investigators',
#    'description': 'Mike Keane writes in The Australian that pilot hijack is the only realistic scenario that makes sense of what is dubbed the greatest aviation mystery in history.',
#    'url': 'http://www.freemalaysiatoday.com/category/nation/2018/08/19/aviation-expert-slams-mh370-investigators/',
#    'urlToImage': 'http://s3media.freemalaysiatoday.com/wp-content/uploads/2018/03/New-search-for-flight-MH370-to-end-mid-June-1.jpg',
#    'publishedAt': '2018-08-19T08:08:29Z'},
#   {'source': {'id': None, 'name': 'Businessinsider.com.au'},
#    'author': 'Ellen Cranley',
#    'title': 'Giuliani just admitted the 2016 Trump Tower meeting was to get dirt on Clinton',
#    'description': 'President Donald Trump’s attorney Rudy Giuliani admitted Sunday that the controversial 2016 meeting at Trump Tower between Trump campaign officials and a Kremlin-linked attorney was to get “dirt” on his Democratic opponent, Hillary Clinton.',
#    'url': 'https://www.businessinsider.com.au/giuliani-trump-tower-meeting-dirt-on-clinton-2018-8',
#    'urlToImage': 'https://static.businessinsider.com/image/5b797b4d2be4ab1d008b5526-640.jpg',
#    'publishedAt': '2018-08-19T06:00:36Z'},
#   {'source': {'id': None, 'name': 'Scmp.com'},
#    'author': 'Brahma Chellaney, Brahma Chellaney',
#    'title': 'Asean’s limits are on display as effort to build a robust Southeast Asian community loses momentum',
#    'description': 'The 10-nation Association of Southeast Asian Nations, despite its lack of cohesiveness and geopolitical heft, likes to be in the driver’s seat even on initiatives that extend beyond its region. But having placed itself at the wheel, Asean usually needs instru…',
#    'url': 'https://www.scmp.com/news/china/diplomacy-defence/article/2160250/aseans-limits-are-display-effort-build-robust-southeast',
#    'urlToImage': 'https://cdn3.i-scmp.com/sites/default/files/styles/620x356/public/images/methode/2018/08/17/aa80ff0c-9f17-11e8-90bf-ccc49f9b020a_image_hires_194901.jpg?itok=OkFlRUCn',
#    'publishedAt': '2018-08-19T05:02:20Z'},
#   {'source': {'id': None, 'name': 'Nationalinterest.org'},
#    'author': 'John Hemmings',
#    'title': 'What China Could Expect from a Global Britain',
#    'description': "John Hemmings Security, Asia London will find ways to compete and cooperate with other navies in the Indian Ocean, such as China's PLAN. As India celebrates seventy-two years of Independence from the British Empire this week, a grand historical milestone for …",
#    'url': 'https://nationalinterest.org/feature/what-china-could-expect-global-britain-29067',
#    'urlToImage': 'https://nationalinterest.org/sites/default/files/main_images/RTXQYIR.jpeg',
#    'publishedAt': '2018-08-19T03:29:00Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
#    'title': 'Victorians to get half-price solar panels under Government scheme',
#    'description': 'Victorians will be able to install solar panels on their home for half price under a $1.24 billion plan announced by the Andrews Government ahead of the upcoming state election.',
#    'url': 'http://www.abc.net.au/news/2018-08-19/victorians-to-get-half-price-solar-panels-in-government-scheme/10137484',
#    'urlToImage': 'http://www.abc.net.au/news/image/7646258-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T02:17:16Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Jade Macmillan',
#    'title': 'Turnbull plans more energy policy changes amid internal pressure',
#    'description': 'Prime Minister Malcolm Turnbull outlines further changes to his national energy policy amid increasing pressure from within his own party.',
#    'url': 'http://www.abc.net.au/news/2018-08-19/labor-unveils-plan-to-cut-power-prices/10137298',
#    'urlToImage': 'http://www.abc.net.au/news/image/8223780-16x9-700x394.jpg',
#    'publishedAt': '2018-08-19T01:55:59Z'},
#   {'source': {'id': None, 'name': 'Legalinsurrection.com'},
#    'author': 'Leslie Eastman',
#    'title': 'Analyzing Interior Secretary Ryan Zinke’s incendiary comments about California wildfires',
#    'description': "129 million dead trees in California show that Zinke's statements contains more truth than rhetoric.",
#    'url': 'https://legalinsurrection.com/2018/08/analyzing-interior-secretary-ryan-zinkes-incendiary-comments-about-california-wildfires/',
#    'urlToImage': 'https://legalinsurrection.com/wp-content/uploads/2016/12/TrumpRyanZinke.jpg',
#    'publishedAt': '2018-08-18T22:30:48Z'},
#   {'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'author': 'Kelsey Munro',
#    'title': 'School choice: some parents are prepared to pay, but is society?',
#    'description': 'Australians going private to ‘find the right fit’ leave a depleted public system in their wake “When our eldest started at his local high school it didn’t have a great reputation – whatever that means – and people audibly gasped when I said we were sending ou…',
#    'url': 'https://www.theguardian.com/australia-news/2018/aug/19/school-choice-some-parents-are-prepared-to-pay-but-is-society',
#    'urlToImage': 'https://i.guim.co.uk/img/media/b722ba5a2b12b60d820ab0c62477e549d27d115f/0_0_5361_3216/master/5361.jpg?w=1200&h=630&q=55&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=2095dd86014b937104dc4723aaeea29d',
#    'publishedAt': '2018-08-18T22:00:02Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Andrew Greene',
#    'title': "RAAF warplane's engine 'destroyed itself', causing $120 million fire",
#    'description': 'Senior military figures describe the "most serious incident of its kind for the Australian Air Force in more than 25 years", praising two pilots for their expert response to a dramatic engine malfunction that saw their advanced warplane skid across a US runwa…',
#    'url': 'http://www.abc.net.au/news/2018-08-19/warplanes-engine-destroyed-itself-during-attempted-take-off/10129180',
#    'urlToImage': 'http://www.abc.net.au/news/image/10131504-16x9-700x394.jpg',
#    'publishedAt': '2018-08-18T19:14:20Z'},
#   {'source': {'id': None, 'name': 'Fark.com'},
#    'author': None,
#    'title': "Rarity and Dash have nothing in common and wonder why they are friends. Is this the end of their relationship? Will they find out they have been married all this time? It's My Little Pony-The End in Friend Saturday on Discovery Family at 11:30am ET [Live]",
#    'description': "Rarity and Dash have nothing in common and wonder why they are friends. Is this the end of their relationship? Will they find out they have been married all this time? It's My Little Pony-The End in Friend Saturday on Discovery Family at 11:30am ET",
#    'url': 'https://www.fark.com/comments/10132427/Rarity-Dash-have-nothing-in-common-wonder-why-they-are-friends-Is-this-end-of-their-relationship-Will-they-find-out-they-have-been-married-all-this-time-Its-My-Little-Pony-The-End-in-Friend-Saturday-on-Discovery-Family-at-1130am-ET',
#    'urlToImage': 'https://img.fark.net/images/cache/orig/f/fi/fark_fivbOZbkCEnkWa_7OAX8vruDb4E.jpg?t=MeIpuZGM8OxmGXTYrGvaSw&f=1534737600',
#    'publishedAt': '2018-08-18T15:00:00Z'},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': 'Anna Henderson',
#    'title': "'We have their backs': Government dramatically ramps up drought funding",
#    'description': 'In an admission of the size and scope of the current drought crisis gripping parts of the nation, the Federal Government will today announce a significant increase in the funding available for struggling communities.',
#    'url': 'http://www.abc.net.au/news/2018-08-19/drought-assistance-to-be-ramped-up-by-turnbull-government/10136318',
#    'urlToImage': 'http://www.abc.net.au/news/image/9800704-16x9-700x394.jpg',
#    'publishedAt': '2018-08-18T14:01:32Z'},
#   {'source': {'id': None, 'name': 'Channelnewsasia.com'},
#    'author': None,
#    'title': 'Commentary: Shinzo Abe’s straightforward path to becoming Japan’s longest-serving PM',
#    'description': "While the world focused on China removing term limits on its presidency, in Japan, Shinzo Abe looks set to become the country's longest-serving prime minister - thanks to a lack of peer competition, says one observer.",
#    'url': 'https://www.channelnewsasia.com/news/commentary/shinzo-abe-road-to-be-japan-longest-serving-prime-minister-10615584',
#    'urlToImage': 'http://www.channelnewsasia.com/image/8160660/16x9/991/529/dd6b232e49c2aaafe9f6b1a866aea813/kJ/japan-s-prime-minister-abe-claps-his-hands-during-the-ruling-liberal-democratic-party-annual-c---2607742.png',
#    'publishedAt': '2018-08-18T09:10:38Z'},
#   {'source': {'id': None, 'name': 'Dw.com'},
#    'author': 'Deutsche Welle (www.dw.com)',
#    'title': 'Pakistan facing multiple crises as PM Imran Khan takes over',
#    'description': "Pakistan's cricketer-turned-politician Imran Khan has taken the oath as prime minister. He faces a multitude of challenges at home and abroad, which experts say he may not be able to master as easily as he thinks.",
#    'url': 'https://www.dw.com/en/pakistan-facing-multiple-crises-as-pm-imran-khan-takes-over/a-45119761',
#    'urlToImage': 'https://www.dw.com/image/45127025_304.jpg',
#    'publishedAt': '2018-08-18T05:36:00Z'}]}

# %%
type(all_articles), len(all_articles)
# Out:
# (dict, 3)

# %%
all_articles.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
all_articles['totalResults'], len(all_articles['articles'])
# Out:
# (798, 100)

# %%
#all_articles['articles']

# %%
all_df = pd.DataFrame(all_articles['articles'])
all_df.head(1).T
#all_df[['title','description']].head()
# Out:
#                                                                                                                                                         0
# author       None
# description  It's on in Australian politics. Prime Minister Malcolm Turnbull will recontest his position, challenging his agitators to put up or shut up.
# publishedAt  2018-08-20T23:18:46Z
# source       {'id': None, 'name': 'Stuff.co.nz'}
# title        Leadership spill declared in Australia
# url          https://www.stuff.co.nz/world/australia/106436672/Leadership-spill-declared-in-Australia
# urlToImage   https://resources.stuff.co.nz/content/dam/images/1/r/d/1/z/j/image.related.StuffLandscapeSixteenByNine.620x349.1rdb28.png/1534807321159.jpg

# %%
#all_df.publishedAt.iloc[[0,1,2]]
# this column needs to be in datetime format

# %% [markdown]
# ### Script to fetch and store all pages of news articles in a dataframe all_df

# %%
# Search terms
# Time period of last 10 days
today=datetime.today().strftime('%Y-%m-%d')
ldate=(datetime.today()-timedelta(days=10)).strftime('%Y-%m-%d')
# Complex query search term must be URL-encoded? Not sure
query = 'Australia Politics'


# get all articles and store in all_df dataframe
all_articles = newsapi.get_everything(q=query,
                                      from_param=ldate,
                                      to=today,
                                      language='en',
                                      sort_by='publishedAt',
                                      page=1, # first page of results
                                      page_size=100)
all_df = pd.DataFrame(all_articles['articles'])

# calculated remaining pages 
pages = int(np.ceil(all_articles['totalResults']/len(all_articles['articles'])))

for p in range(2,pages+1):
    results = pd.DataFrame(newsapi.get_everything(q='Australia Politics',
                                  from_param=ldate,
                                  to=today,
                                  language='en',
                                  sort_by='publishedAt',
                                  page=p,
                                  page_size=100)['articles']
                        )
    # append returns new object so reassign to all_df
    all_df = all_df.append(results, ignore_index=True)

# %%
# check all results fetched
len(all_df),all_articles['totalResults'], pages
# Out:
# (482, 482, 5)

# %%
all_df.iloc[-1],results.iloc[-1]
# Out:
# (author         Krystal Gordon
#  description    Outback Queensland Mayor Geoff Morton apologises for sending nude photos of himself via the Diamantina Shire Council's email system.
#  publishedAt    2018-08-31T00:25:55Z
#  source         {'id': 'abc-news-au', 'name': 'ABC News (AU)'}
#  title          Mayor apologises for emailing nude photos on council email system
#  url            http://www.abc.net.au/news/2018-08-31/diamantina-mayor-geoff-morton-apologises-for-nude-photos-email/10186742
#  urlToImage     http://www.abc.net.au/news/image/6750112-16x9-700x394.jpg
#  Name: 481, dtype: object,
#  author         Krystal Gordon
#  description    Outback Queensland Mayor Geoff Morton apologises for sending nude photos of himself via the Diamantina Shire Council's email system.
#  publishedAt    2018-08-31T00:25:55Z
#  source         {'id': 'abc-news-au', 'name': 'ABC News (AU)'}
#  title          Mayor apologises for emailing nude photos on council email system
#  url            http://www.abc.net.au/news/2018-08-31/diamantina-mayor-geoff-morton-apologises-for-nude-photos-email/10186742
#  urlToImage     http://www.abc.net.au/news/image/6750112-16x9-700x394.jpg
#  Name: 81, dtype: object)

# %%
# convert nested dict 'source' column to columns
source_df=pd.DataFrame(list(all_df.source))
all_df[['source_id','source_name']]=source_df[['id','name']]

# Can drop the source column to save memory
all_df.drop(columns=['source'],inplace=True)

# convert to datetime
all_df['publishedAt'] =  pd.to_datetime(all_df['publishedAt'])

# %%
all_df.tail(1).T
# Out:
#                                                                                                                                               481
# author       Krystal Gordon
# description  Outback Queensland Mayor Geoff Morton apologises for sending nude photos of himself via the Diamantina Shire Council's email system.
# publishedAt  2018-08-31 00:25:55
# title        Mayor apologises for emailing nude photos on council email system
# url          http://www.abc.net.au/news/2018-08-31/diamantina-mayor-geoff-morton-apologises-for-nude-photos-email/10186742
# urlToImage   http://www.abc.net.au/news/image/6750112-16x9-700x394.jpg
# source_id    abc-news-au
# source_name  ABC News (AU)

# %%
#potential to use this
all_df.publishedAt.diff(-1).tail(3) # time difference to next row e.g. diff(row0->row1) = 55seconds
# Out:
# 479   00:12:11
# 480   00:22:32
# 481   NaT
# Name: publishedAt, dtype: timedelta64[ns]

# %% [markdown]
# ### Get results from AWS comprehend API

# %%
str3 = all_df['description'][0]+all_df['description'][1]
print(str3)
# Out:
# Around 100 kilometres off the coast of Darwin, HMAS Newcastle achieves what lawmakers have struggled to do: come together with the Chinese to learn more about each other.Antony Green says he feels safe calling Saturday's by-election slightly more than 24 hours after the polls closed, as Labor scrutineer figures suggest the gap is too big to close.

# %%
comprehend = boto3.client(service_name='comprehend', region_name='us-east-2')
                
text = str3

print(json.dumps(comprehend.detect_entities(Text=text,LanguageCode='en'), sort_keys=True, indent=4))
# Out:
# {
#     "Entities": [
#         {
#             "BeginOffset": 7,
#             "EndOffset": 21,
#             "Score": 0.9937576055526733,
#             "Text": "100 kilometres",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 39,
#             "EndOffset": 45,
#             "Score": 0.8912165760993958,
#             "Text": "Darwin",
#             "Type": "LOCATION"
#         },
#         {
#             "BeginOffset": 47,
#             "EndOffset": 61,
#             "Score": 0.6855267882347107,
#             "Text": "HMAS Newcastle",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 131,
#             "EndOffset": 138,
#             "Score": 0.5261865258216858,
#             "Text": "Chinese",
#             "Type": "LOCATION"
#         },
#         {
#             "BeginOffset": 170,
#             "EndOffset": 182,
#             "Score": 0.9983832836151123,
#             "Text": "Antony Green",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 210,
#             "EndOffset": 218,
#             "Score": 0.9843761920928955,
#             "Text": "Saturday",
#             "Type": "DATE"
#         },
#         {
#             "BeginOffset": 242,
#             "EndOffset": 260,
#             "Score": 0.9377206563949585,
#             "Text": "more than 24 hours",
#             "Type": "QUANTITY"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "connection": "keep-alive",
#             "content-length": "721",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Mon, 10 Sep 2018 10:32:55 GMT",
#             "x-amzn-requestid": "e0b08cd4-b4e4-11e8-b992-7d77f5991936"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "e0b08cd4-b4e4-11e8-b992-7d77f5991936",
#         "RetryAttempts": 0
#     }
# }

# %%
str3[236:243]
# Out:
# 'Chinese'

# %%
# i=1
# j=0
# while i <5:
#     str1 = ''.join(Description[j:i])
#     check=json.dumps(comprehend.detect_entities(Text=str1,LanguageCode='en'), sort_keys=True, indent=4)
#     check2=comprehend.detect_entities(Text=str1,LanguageCode='en')
#     #print(json.dumps(comprehend.detect_entities(Text=str1,LanguageCode='en'), sort_keys=True, indent=4))
#     #print(i)
#     #print(str1)
#     i+=1
#     j+=1

# %% [markdown]
# ### Try Spacy

# %% [markdown]
# https://spacy.io/usage/spacy-101

# %%
# Need to install spacy and english model - large files and takes time to install

# pip install spacy
# python -m spacy download en

# %%
nlp = spacy.load('en')
doc=nlp(str3)
print([t.text for t in doc])
# Out:
# ['Around', '100', 'kilometres', 'off', 'the', 'coast', 'of', 'Darwin', ',', 'HMAS', 'Newcastle', 'achieves', 'what', 'lawmakers', 'have', 'struggled', 'to', 'do', ':', 'come', 'together', 'with', 'the', 'Chinese', 'to', 'learn', 'more', 'about', 'each', 'other', '.', 'Antony', 'Green', 'says', 'he', 'feels', 'safe', 'calling', 'Saturday', "'s", 'by', '-', 'election', 'slightly', 'more', 'than', '24', 'hours', 'after', 'the', 'polls', 'closed', ',', 'as', 'Labor', 'scrutineer', 'figures', 'suggest', 'the', 'gap', 'is', 'too', 'big', 'to', 'close', '.']

# %%
# sentences
list(doc.sents)[0].text
# Out:
# 'Around 100 kilometres off the coast of Darwin, HMAS Newcastle achieves what lawmakers have struggled to do: come together with the Chinese to learn more about each other.'

# %%
# Named entity recognition
nlp = spacy.load('en')
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
doc=nlp(str3)

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Around 100 kilometres 0 21 QUANTITY
# Darwin 39 45 PERSON
# HMAS 47 51 ORG
# Newcastle 52 61 GPE
# Chinese 131 138 NORP
# Antony Green 170 182 PERSON
# Saturday 210 218 DATE
# more than 24 hours 242 260 TIME
# Labor 288 293 ORG

# %%
# Spacy vizs
from spacy import displacy
nlp = spacy.load('en')
doc = nlp(str3)
displacy.render(doc, style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Around 100 kilometres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  off the coast of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Darwin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     HMAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Newcastle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  achieves what lawmakers have struggled to do: come together with the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  to learn more about each other.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Antony Green
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  says he feels safe calling
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's by-election slightly
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     more than 24 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  after the polls closed, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Labor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  scrutineer figures suggest the gap is too big to close.</div>

# %%
sentence_spans = list(doc.sents)
#displacy.serve(sentence_spans, style='dep')
displacy.render(sentence_spans[0], style='dep',jupyter=True, options={'distance':50})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1450" height="287.0" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="100">100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">kilometres</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">off</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">coast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Darwin,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">HMAS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Newcastle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">achieves</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">lawmakers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">struggled</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">do:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="900">come</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">together</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1000">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Chinese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1200">learn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1300">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">other.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,152.0 C70,127.0 75.0,127.0 75.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M120,152.0 C120,127.0 125.0,127.0 125.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentC

# %%
# Similarity
#Using basic model 'en' aka en_core_web_sm

tokens = nlp(u'dog cat banana')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.5390697
# dog banana 0.28761008
# cat dog 0.5390697
# cat cat 1.0
# cat banana 0.48752153
# banana dog 0.28761008
# banana cat 0.48752153
# banana banana 1.0

# %%
# This is using a larger model that is 115MB vs 35MB for the 'en'. And takes time to load
# More accurate as it comes with pretrained word embedding vectors
nlp = spacy.load('en_core_web_md')
tokens = nlp(u'dog cat banana')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.8016855
# dog banana 0.24327648
# cat dog 0.8016855
# cat cat 1.0
# cat banana 0.2815437
# banana dog 0.24327648
# banana cat 0.2815437
# banana banana 1.0

# %%
doc = nlp(u"Peach emoji is where it has always been. Peach is the superior "
          u"emoji. It's outranking eggplant 🍑 ")
print(doc[0].text)          # Peach
print(doc[1].text)          # emoji
print(doc[-1].text)         # 🍑
print(doc[17:19].text)      # outranking eggplant

noun_chunks = list(doc.noun_chunks)
print(noun_chunks[0].text)  # Peach emoji

sentences = list(doc.sents)
assert len(sentences) == 3
print(sentences[1].text)    # 'Peach is the superior emoji.'
# Out:
# Peach
# emoji
# 🍑
# outranking eggplant
# Peach emoji
# Peach is the superior emoji.

# %%
doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
apple = doc[0]
print('Fine-grained POS tag', apple.pos_, apple.pos)
print('Coarse-grained POS tag', apple.tag_, apple.tag)
print('Word shape', apple.shape_, apple.shape)
print('Alphanumeric characters?', apple.is_alpha)
print('Punctuation mark?', apple.is_punct)

billion = doc[10]
print('Digit?', billion.is_digit)
print('Like a number?', billion.like_num)
print('Like an email address?', billion.like_email)
# Out:
# Fine-grained POS tag PROPN 95
# Coarse-grained POS tag NNP 15794550382381185553
# Word shape Xxxxx 16072095006890171862
# Alphanumeric characters? True
# Punctuation mark? False
# Digit? False
# Like a number? True
# Like an email address? False
